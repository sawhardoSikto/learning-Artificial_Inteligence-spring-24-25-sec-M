# %%
print("Hello World")
#declear variable
name ="sikto";
name1="""biswas
is a good boy"""
print(name);
print(name1);

print(type(name1));

complex1=3+4j;
complex2=1+4j;
sum=complex1+complex2;
print(sum,type(sum));

d1=5;
d2=2;
div=d1//d2;
print(div);

e1=5;
e2=5;
exp=e1**e2;
print(exp)


x=10;
y=5;
print("x==y",x==y);



#input

age1=input("enter your age1");
age2=input("enter your age2");
AGE1=int(age1)
AGE2=int(age2);
print(AGE1+AGE2)
# Out:
# Hello World
# sikto
# biswas
# is a good boy
# <class 'str'>
# (4+8j) <class 'complex'>
# 2
# 3125
# x==y False
# enter your age115
# enter your age223
# 38

# %%
a=int(input("enter yout age for validadion "))
if a>=18:
  print("you can vote")
else:
  print("you can not vote")

print("_______________");
# Out:
# enter yout age for validadion 66
# you can vote
# _______________

# %%
name="  sikto   ";

print(name.strip())
# Out:
# sikto

# %%
name="aiub";
print(name.upper())
# Out:
# AIUB

# %% [markdown]
# list

# %%
id_number=[3,4,5,6,3];
sort=id_number.sort()
print(sort)
# Out:
# None

# %% [markdown]
# list and tuple
# list and tuple er moddhe difference hocche list holo mutable mane etake change kora jay ar tuple holo immutable jeta kina change kora jay na

# %%
itemlist=[10,415,12,2,4] # list
print(itemlist)
itemlist.remove(10)
itemlist.append(100)
itemlist[1]=23;
print(itemlist)
item=(12,45,5,454)#tuple
print (item)
item1= (10,"hello",3.1416,True);
print(item1)
# Out:
# [10, 415, 12, 2, 4]
# [415, 23, 2, 4, 100]
# (12, 45, 5, 454)
# (10, 'hello', 3.1416, True)

# %% [markdown]
# mathemetical operatin

# %%
item=(10,20,30,40,50);
print(max(item))
print(min(item))
print(sum(item))
# Out:
# 50
# 10
# 150

# %% [markdown]
# dictonary

# %%
student ={"name":"sikto", "id":"22-474062-2", "cgpa":3.71}
print(student.values())
print(student["id"]);
student ={"name":"sikto", "id":"22-474062-2", "cgpa":3.71}
print(student.values())
print(student["id"]);
print(student.keys())
print(student.items())
student.update({"name":"sikto biswas"})
print (student)
# Out:
# dict_values(['sikto', '22-474062-2', 3.71])
# 22-474062-2
# dict_values(['sikto', '22-474062-2', 3.71])
# 22-474062-2
# dict_keys(['name', 'id', 'cgpa'])
# dict_items([('name', 'sikto'), ('id', '22-474062-2'), ('cgpa', 3.71)])
# {'name': 'sikto biswas', 'id': '22-474062-2', 'cgpa': 3.71}

# %% [markdown]
# function

# %%
def student():

    print("helo everyone")

student();
# Out:
# helo everyone

# %% [markdown]
# file handaling

# %%
file= open("hello.txt","r")
content =file.read();
print(conten);
file.close()




line =["hello "];
file1=open("hello.txt","w");
file1.writelines(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-5e0b13ce1a95> in <cell line: 0>()
# ----> 1 file= open("hello.txt","r")
#       2 content =file.read();
#       3 print(content);
#       4 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hello.txt'
